# %% [markdown]
# # Scenario description

# %% [markdown]
# ### This scenario is a set of 100 000 transactions between 1500 accounts. There are no malicious or any other extraordinary transactions within this particular scenario. The transaction frequency grows as a function of time (square root of 0.75t). The initial token supply is equal to 1000 000 000 tokens. The fee is currently fixed and equals to 20 tokens per transaction. The transactions start on 2018-04-01 11:00:00 and stop on 2018-07-01 11:00:00. The emission takes place weekly.

# %% [markdown]
# ### Initially all the tokens are on the genesis account (address 'g6058z5762i1084'). This account does not receive tokens and distributes (almost) all of the tokens to the first 200 accounts in roughly equal amounts.

# %% [markdown]
# ### The types of accounts in the system are: hodlers, businesses, sellers, buyers, and an exchange ('g1791u5098w9228'). Any account can deposit tokens to the exchange for trading or withdraw tokens onto their wallet. Any two accounts are allowed to transact with each other. There are 50% of hodlers, or relatively inactive accounts, 25% of sellers who behave in a mildly speculative manner, and 25% of buyers who try to gradually accumulate wealth.

# %% [markdown]
# ### The types of accounts in the system are defined in a probabilistic manner. A transaction is formed by a random selection of a sender and a receiver, and the types of accounts each have probabilities of sending or receiving an amount of tokens. Probabilities of sending a transaction by account type: {'exchange' : 0.005, 'genesis' : 0.005, 'buyer' : 0.33, 'seller' : 0.6, 'hodler' : 0.06}. The genesis address does not send tokens after the initial distribution. Probabilities of receiving a transaction by account type: {'exchange' : 0.05, 'genesis' : 0, 'buyer' : 0.55, 'seller' : 0.25, 'hodler' : 0.15}. Here we see, for example, that a hodler has a much higher probability of purchasing tokens rather then selling them, but is altogether less active than other users. This probability proportion is what defines a role in the system.

# %% [markdown]
# ### The minimum transaction amount threshold is 1000 tokens. The amount sent by an account is a random amount between the minimum threshold and 30% of the sender's current balance. If an account tries to send a smaller amount, it does not go through.

# %% [markdown]
# ### Another account subtype in the system is a business, an address that accepts the tokens as a payment for their services. In the system the businesses do not accumulate wealth and go on to send their tokens further, but are a frequent receiver of transactions. Each business account has a set number of clients in the system.

# %% [markdown]
# ### The number of businesses in the scenario is equal to 8. The number of clients of each business is equal to [20, 30, 80, 20, 15, 25, 18, 10]. A business-to-customer transaction takes place with a 40% probability and a customer-to-business transaction with a 60% probability. The number of business-related transactions in the system is equal to 10% of all transaction, or roughly 10 000. The amount of a business transaction is a random amount between the minimum threshold and 40% of the sender's current account.

# %% [markdown]
# ## The aim of this scenario is to create a standard setting that would develop slowly and organically, and to see the dynamics of system, the balances, volumes, emission, system and account activity, and gravity index, all grouped by account types. The observed dynamics is then compared with a set transaction with malicious accounts intending to compromise or manipulate the system by transacting very intensely or creating clusters within the system. The system parameters are tuned to neutralize malicious activity. It is to be shown that an attack is too expensive to carry out and does not give a financial incentive.

# %% [markdown]
# ## Сumulative new accounts registering weekly (by first transaction)

# %% [markdown]
# ## Total balance distribution weekly

# %% [markdown]
# ## Weekly sending transactions by account type

# %% [markdown]
# ## Weekly receiving transactions by account type

# %% [markdown]
# ## Traded token volume weekly by account type

# %% [markdown]
# ## Weekly account activity index by account type

# %% [markdown]
# ## Weekly Gravity index by account type

# %% [markdown]
# ## Weekly emission grouped by account type

# %% [markdown]
# ## System activity

# %% [markdown]
# ## Typical account behavior: exchange, buyer, seller, hodler, businesses

# %% [markdown]
# ### Below we can see the balance dynamics of typical representatives of the account types.

# %%
exchange = 'g1791u5098w9228'
buyer = 'g2862x9047t7620'
seller = 'g5786v1379d3010'
hodler = 'g1423r1616u9567'
businesses = ['g6924y1671j9109','g6567s7669t5663','g3876a6905z5179','g5226b7996j5986',
              'g4572u5286z2037','g3840w6875m5321','g1674i9707z6897','g4050f4167s9245']

# %% [markdown]
# ## Emission-to-fees ratio of typical representatives

# %%
# Out:
# g1423r1616u9567 Hodler
# Emission: 6021.0 Fees: 120.0 Total emission to fees: 50.175
#
# g2862x9047t7620 Buyer
# Emission: 8079.83 Fees: 1400.0 Total emission to fees: 5.771307142857143
#
# g5786v1379d3010 Seller
# Emission: 2689.37 Fees: 3340.0 Total emission to fees: 0.8052005988023951
#
# g6567s7669t5663 Business
# Emission: 33126.3 Fees: 9300.0 Total emission to fees: 3.5619677419354843
#
# g6924y1671j9109 Business
# Emission: 30760.2 Fees: 7480.0 Total emission to fees: 4.112326203208556

# %%
# Out:
# User: exchange Address: g1791u5098w9228

# %%
# Out:
# User: buyer Address: g2862x9047t7620

# %%
# Out:
# User: hodler Address: g1423r1616u9567

# %%
# Out:
# User: seller Address: g5786v1379d3010

# %%
# Out:
# User: business Address: g6567s7669t5663

# %% [markdown]
# ## Account activity weekly

# %%
plt.show()

# %% [markdown]
# ## Fees and transaction count

# %%
# Out:
# Total fees: 1923200.0 Transaction count: 96160.0

# %% [markdown]
# ## 20% of tokens held by the richest wallets (meaning accounts)

# %%
# Out:
# 64 wallets hold 201572240.0 tokens

# %% [markdown]
# ## Emission received by businesses weekly
